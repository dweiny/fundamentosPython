# %% [markdown]
# # ***Lists***

# %% [markdown]
# ##### *Estructures of data for create of codes of form more less.*

# %%
myList = []
print(type(myList)) # type of list
# Out:
# <class 'list'>

# %% [markdown]
# ## **Matrices**

# %%
list1 = [1, 2, 3]
list2 = [4, 5, 6]
list3 = [7, 8, 9]
list4 = [list1, list2, list3]
print(list4[0][0])
print(list4[0][1])
print(list4[0][2])
# Out:
# 1
# 2
# 3

# %% [markdown]
# ## **List Functions**

# %%
listExemple = [1, 2, 3]
listExemple.append(4) # add elements in final of list
listExemple.pop() # remove the last element of list
listX = ['e', 'c', 'a', 'd', 'b'] 
listX.sort() # reorders elements of list in correct ordem
listX.reverse() # reorders elements of list in reverse




# WITH TIME LIBRARY:
# import time
# print("Last list: ")
# time.sleep(2)
# print(listX)
# time.sleep(3)
# print("New list: ")
# time.sleep(2)
# print(listO)
# Out:
# None
