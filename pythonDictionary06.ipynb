# %% [markdown]
# # **Python Dictionary**

# %% [markdown]
# #### *Key & Value*

# %%
from pprint import pprint
myDictionary = {"name": "Davi", "secondName": "Weiny", "lastName": "da Silva", "age": 16, "tall": 1.76,}
# pprint(myDictionary)

print(myDictionary["name"],myDictionary["secondName"],myDictionary["lastName"])
# Out:
# Davi Weiny da Silva
