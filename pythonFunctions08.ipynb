# %% [markdown]
# # **Python Functions**

# %% [markdown]
# ### *Sintaxe of Functions*
#
# def nameFunction (Here I can or can't have arguments/parameters) :
#     '''
#         Here I insert the documentation of function
#     '''
#     # Your function in action
#
#     return # Can or can't have "return", where his function are return something

# %%
# Function without arguments and return
def introduction():
    print("Hello World!")


introduction()

# %%
# Function with argument
def cumpriment(name):
    print(f"Hello {name}")

cumpriment("Davi")
# Out:
# Hello Davi

# %%
# Function print bigger number
def bigger (x,y):
    if x>y:
        print(x)
    else:
        print(y)

bigger(10, 15)
# Out:
# 15

# %%
# Function with return
def addNum(num1, num2):
    result1 = (5,5)
    result2 = (10,10)
    # return num1+num2

# %%
# Baskara function
# Pitagoras function
# Sinonimous function
